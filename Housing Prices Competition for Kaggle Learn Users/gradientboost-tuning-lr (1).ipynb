# %% [markdown]
# ## Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
path = '/kaggle/input/home-data-for-ml-course/'
train = pd.read_csv(path+'/train.csv')
test = pd.read_csv(path+'/test.csv')

# %% [markdown]
# ## Train Data
# Instead of just simply printing train.head() i have used '.style' which shows all columns.
#
# I have selected ".background_gradient(cmap = "magma") but there are some other options like "plasma," "inferno," and "magma."
#
# It will show color variation for numerical data only.

# %%
train.head(10).style.background_gradient(cmap= "magma")
# Out:
# <style type="text/css">
# #T_45b02_row0_col0, #T_45b02_row0_col18, #T_45b02_row0_col36, #T_45b02_row0_col45, #T_45b02_row0_col48, #T_45b02_row0_col52, #T_45b02_row0_col56, #T_45b02_row0_col66, #T_45b02_row0_col68, #T_45b02_row0_col69, #T_45b02_row0_col70, #T_45b02_row0_col71, #T_45b02_row0_col75, #T_45b02_row1_col1, #T_45b02_row1_col26, #T_45b02_row1_col36, #T_45b02_row1_col44, #T_45b02_row1_col45, #T_45b02_row1_col47, #T_45b02_row1_col50, #T_45b02_row1_col52, #T_45b02_row1_col67, #T_45b02_row1_col68, #T_45b02_row1_col69, #T_45b02_row1_col70, #T_45b02_row1_col71, #T_45b02_row1_col75, #T_45b02_row2_col18, #T_45b02_row2_col36, #T_45b02_row2_col45, #T_45b02_row2_col48, #T_45b02_row2_col52, #T_45b02_row2_col66, #T_45b02_row2_col68, #T_45b02_row2_col69, #T_45b02_row2_col70, #T_45b02_row2_col71, #T_45b02_row2_col75, #T_45b02_row3_col18, #T_45b02_row3_col19, #T_45b02_row3_col26, #T_45b02_row3_col36, #T_45b02_row3_col38, #T_45b02_row3_col45, #T_45b02_row3_col48, #T_45b02_row3_col49, #T_45b02_row3_col50, #T_45b02_row3_col52, #T_45b02_row3_col66, #T_45b02_row3_col69, #T_45b02_row3_col70, #T_45b02_row3_col71, #T_45b02_row3_col75, #T_45b02_row3_col77, #T_45b02_row4_col18, #T_45b02_row4_col36, #T_45b02_row4_col45, #T_45b02_row4_col48, #T_45b02_row4_col52, #T_45b02_row4_col68, #T_45b02_row4_col69, #T_45b02_row4_col70, #T_45b02_row4_col71, #T_45b02_row4_col75, #T_45b02_row5_col17, #T_45b02_row5_col18, #T_45b02_row5_col26, #T_45b02_row5_col36, #T_45b02_row5_col37, #T_45b02_row5_col43, #T_45b02_row5_col45, #T_45b02_row5_col48, #T_45b02_row5_col49, #T_45b02_row5_col51, #T_45b02_row5_col52, #T_45b02_row5_col54, #T_45b02_row5_col56, #T_45b02_row5_col68, #T_45b02_row5_col70, #T_45b02_row5_col71, #T_45b02_row6_col1, #T_45b02_row6_col18, #T_45b02_row6_col36, #T_45b02_row6_col44, #T_45b02_row6_col45, #T_45b02_row6_col48, #T_45b02_row6_col50, #T_45b02_row6_col52, #T_45b02_row6_col68, #T_45b02_row6_col69, #T_45b02_row6_col70, #T_45b02_row6_col71, #T_45b02_row6_col75, #T_45b02_row7_col45, #T_45b02_row7_col48, #T_45b02_row7_col52, #T_45b02_row7_col69, #T_45b02_row7_col70, #T_45b02_row7_col71, #T_45b02_row8_col4, #T_45b02_row8_col18, #T_45b02_row8_col20, #T_45b02_row8_col26, #T_45b02_row8_col34, #T_45b02_row8_col36, #T_45b02_row8_col45, #T_45b02_row8_col47, #T_45b02_row8_col48, #T_45b02_row8_col50, #T_45b02_row8_col59, #T_45b02_row8_col67, #T_45b02_row8_col69, #T_45b02_row8_col70, #T_45b02_row8_col71, #T_45b02_row8_col75, #T_45b02_row9_col3, #T_45b02_row9_col17, #T_45b02_row9_col20, #T_45b02_row9_col26, #T_45b02_row9_col36, #T_45b02_row9_col44, #T_45b02_row9_col45, #T_45b02_row9_col46, #T_45b02_row9_col48, #T_45b02_row9_col49, #T_45b02_row9_col50, #T_45b02_row9_col54, #T_45b02_row9_col61, #T_45b02_row9_col62, #T_45b02_row9_col66, #T_45b02_row9_col68, #T_45b02_row9_col69, #T_45b02_row9_col70, #T_45b02_row9_col71, #T_45b02_row9_col75, #T_45b02_row9_col76, #T_45b02_row9_col80 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col1, #T_45b02_row2_col1, #T_45b02_row4_col1, #T_45b02_row7_col1 {
#   background-color: #4a1079;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col3, #T_45b02_row1_col4 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col4, #T_45b02_row3_col3 {
#   background-color: #5f187f;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col17, #T_45b02_row0_col51, #T_45b02_row0_col77, #T_45b02_row1_col51, #T_45b02_row2_col17, #T_45b02_row2_col51, #T_45b02_row2_col77, #T_45b02_row3_col17, #T_45b02_row3_col51, #T_45b02_row4_col77, #T_45b02_row6_col0, #T_45b02_row6_col51, #T_45b02_row7_col17, #T_45b02_row7_col51, #T_45b02_row8_col17, #T_45b02_row8_col77, #T_45b02_row9_col77 {
#   background-color: #f1605d;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col19 {
#   background-color: #fcf9bb;
#   color: #000000;
# }
# #T_45b02_row0_col20 {
#   background-color: #fcecae;
#   color: #000000;
# }
# #T_45b02_row0_col26 {
#   background-color: #cf4070;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col34, #T_45b02_row1_col43 {
#   background-color: #bd3977;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col37 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col38 {
#   background-color: #160f3b;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col43 {
#   background-color: #0b0924;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col44 {
#   background-color: #fea571;
#   color: #000000;
# }
# #T_45b02_row0_col46 {
#   background-color: #d0416f;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col47, #T_45b02_row0_col49, #T_45b02_row0_col50, #T_45b02_row1_col18, #T_45b02_row1_col48, #T_45b02_row1_col49, #T_45b02_row1_col66, #T_45b02_row2_col47, #T_45b02_row2_col49, #T_45b02_row2_col50, #T_45b02_row3_col47, #T_45b02_row3_col61, #T_45b02_row3_col68, #T_45b02_row4_col4, #T_45b02_row4_col17, #T_45b02_row4_col26, #T_45b02_row4_col44, #T_45b02_row4_col46, #T_45b02_row4_col47, #T_45b02_row4_col49, #T_45b02_row4_col50, #T_45b02_row4_col51, #T_45b02_row4_col54, #T_45b02_row4_col61, #T_45b02_row4_col62, #T_45b02_row4_col76, #T_45b02_row5_col3, #T_45b02_row5_col47, #T_45b02_row5_col50, #T_45b02_row5_col69, #T_45b02_row5_col75, #T_45b02_row5_col77, #T_45b02_row6_col17, #T_45b02_row6_col19, #T_45b02_row6_col20, #T_45b02_row6_col34, #T_45b02_row6_col38, #T_45b02_row6_col43, #T_45b02_row6_col47, #T_45b02_row6_col49, #T_45b02_row6_col59, #T_45b02_row6_col80, #T_45b02_row7_col36, #T_45b02_row7_col47, #T_45b02_row7_col49, #T_45b02_row7_col50, #T_45b02_row7_col56, #T_45b02_row7_col67, #T_45b02_row7_col77, #T_45b02_row8_col37, #T_45b02_row8_col49, #T_45b02_row8_col52, #T_45b02_row8_col56, #T_45b02_row9_col0, #T_45b02_row9_col1, #T_45b02_row9_col47, #T_45b02_row9_col52, #T_45b02_row9_col56 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_45b02_row0_col54, #T_45b02_row8_col54, #T_45b02_row8_col68 {
#   background-color: #fc8961;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col59 {
#   background-color: #fcf7b9;
#   color: #000000;
# }
# #T_45b02_row0_col61, #T_45b02_row1_col56, #T_45b02_row1_col61, #T_45b02_row2_col56, #T_45b02_row2_col61, #T_45b02_row3_col54, #T_45b02_row3_col56, #T_45b02_row4_col56, #T_45b02_row5_col61, #T_45b02_row6_col54, #T_45b02_row6_col56, #T_45b02_row6_col61, #T_45b02_row7_col54, #T_45b02_row7_col61, #T_45b02_row7_col75, #T_45b02_row8_col61 {
#   background-color: #b73779;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col62, #T_45b02_row1_col38 {
#   background-color: #c83e73;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col67 {
#   background-color: #641a80;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col76, #T_45b02_row3_col76 {
#   background-color: #120d31;
#   color: #f1f1f1;
# }
# #T_45b02_row0_col80, #T_45b02_row4_col34, #T_45b02_row4_col37 {
#   background-color: #ad347c;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col0, #T_45b02_row9_col59 {
#   background-color: #180f3d;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col3, #T_45b02_row6_col66 {
#   background-color: #febb81;
#   color: #000000;
# }
# #T_45b02_row1_col17, #T_45b02_row1_col77, #T_45b02_row3_col0, #T_45b02_row6_col77, #T_45b02_row7_col18, #T_45b02_row8_col51, #T_45b02_row9_col18, #T_45b02_row9_col51 {
#   background-color: #721f81;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col19, #T_45b02_row7_col26 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col20 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col34, #T_45b02_row6_col3, #T_45b02_row8_col44 {
#   background-color: #f8765c;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col37 {
#   background-color: #4f127b;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col46 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col54, #T_45b02_row2_col54, #T_45b02_row8_col43, #T_45b02_row9_col38 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col59 {
#   background-color: #e34e65;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col62 {
#   background-color: #8e2a81;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col76, #T_45b02_row3_col20 {
#   background-color: #7e2482;
#   color: #f1f1f1;
# }
# #T_45b02_row1_col80 {
#   background-color: #732081;
#   color: #f1f1f1;
# }
# #T_45b02_row2_col0 {
#   background-color: #440f76;
#   color: #f1f1f1;
# }
# #T_45b02_row2_col3 {
#   background-color: #bc3978;
#   color: #f1f1f1;
# }
# #T_45b02_row2_col4, #T_45b02_row2_col46 {
#   background-color: #e85362;
#   color: #

# %% [markdown]
# As we can see data with higer values have lighter color.

# %% [markdown]
# Instead of using '.describe()' I have used '.T' to show it vertically.

# %%
train.describe().T.style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_4783f_row0_col0, #T_4783f_row1_col0, #T_4783f_row3_col0, #T_4783f_row4_col0, #T_4783f_row5_col0, #T_4783f_row6_col0, #T_4783f_row7_col0, #T_4783f_row9_col0, #T_4783f_row10_col0, #T_4783f_row11_col0, #T_4783f_row12_col0, #T_4783f_row13_col0, #T_4783f_row14_col0, #T_4783f_row15_col0, #T_4783f_row16_col0, #T_4783f_row17_col0, #T_4783f_row18_col0, #T_4783f_row19_col0, #T_4783f_row20_col0, #T_4783f_row21_col0, #T_4783f_row22_col0, #T_4783f_row23_col0, #T_4783f_row24_col0, #T_4783f_row26_col0, #T_4783f_row27_col0, #T_4783f_row28_col0, #T_4783f_row29_col0, #T_4783f_row30_col0, #T_4783f_row31_col0, #T_4783f_row32_col0, #T_4783f_row33_col0, #T_4783f_row34_col0, #T_4783f_row35_col0, #T_4783f_row36_col0, #T_4783f_row37_col0, #T_4783f_row37_col1, #T_4783f_row37_col2, #T_4783f_row37_col3, #T_4783f_row37_col4, #T_4783f_row37_col5, #T_4783f_row37_col6, #T_4783f_row37_col7 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_4783f_row0_col1, #T_4783f_row0_col2, #T_4783f_row0_col5, #T_4783f_row0_col6, #T_4783f_row9_col2, #T_4783f_row9_col7, #T_4783f_row11_col2, #T_4783f_row12_col1, #T_4783f_row12_col2, #T_4783f_row12_col4, #T_4783f_row12_col5, #T_4783f_row12_col6, #T_4783f_row13_col1, #T_4783f_row13_col2, #T_4783f_row13_col4, #T_4783f_row13_col5, #T_4783f_row13_col6, #T_4783f_row13_col7, #T_4783f_row14_col2, #T_4783f_row16_col2, #T_4783f_row16_col7, #T_4783f_row34_col2 {
# #T_4783f_row6_col1, #T_4783f_row6_col6, #T_4783f_row7_col1, #T_4783f_row7_col6, #T_4783f_row12_col7, #T_4783f_row13_col3, #T_4783f_row16_col1, #T_4783f_row16_col3, #T_4783f_row16_col4, #T_4783f_row16_col5, #T_4783f_row16_col6, #T_4783f_row25_col1, #T_4783f_row25_col6, #T_4783f_row36_col1, #T_4783f_row36_col6 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_4783f_row6_col4, #T_4783f_row6_col5, #T_4783f_row7_col4, #T_4783f_row7_col5, #T_4783f_row25_col4, #T_4783f_row25_col5, #T_4783f_row36_col4, #T_4783f_row36_col5 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_4783f_row8_col0 {
#   background-color: #fcf0b2;
#   color: #000000;
# }
# #T_4783f_row25_col0 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_4783f_row34_col7 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4783f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4783f_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4783f_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4783f_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4783f_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4783f_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4783f_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_4783f_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_4783f_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4783f_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_4783f_row0_col0" class="data row0 col0" >1460.000000</td>
#       <td id="T_4783f_row0_col1" class="data row0 col1" >730.500000</td>
#       <td id="T_4783f_row0_col2" class="data ro

# %%
test.tail(10).style.background_gradient()
# Out:
# <style type="text/css">
# #T_fe172_row0_col0, #T_fe172_row0_col3, #T_fe172_row0_col4, #T_fe172_row0_col17, #T_fe172_row0_col20, #T_fe172_row0_col26, #T_fe172_row0_col36, #T_fe172_row0_col44, #T_fe172_row0_col45, #T_fe172_row0_col46, #T_fe172_row0_col48, #T_fe172_row0_col49, #T_fe172_row0_col50, #T_fe172_row0_col51, #T_fe172_row0_col52, #T_fe172_row0_col54, #T_fe172_row0_col56, #T_fe172_row0_col61, #T_fe172_row0_col62, #T_fe172_row0_col66, #T_fe172_row0_col67, #T_fe172_row0_col68, #T_fe172_row0_col69, #T_fe172_row0_col70, #T_fe172_row0_col71, #T_fe172_row0_col75, #T_fe172_row0_col76, #T_fe172_row0_col77, #T_fe172_row1_col3, #T_fe172_row1_col4, #T_fe172_row1_col17, #T_fe172_row1_col18, #T_fe172_row1_col26, #T_fe172_row1_col36, #T_fe172_row1_col38, #T_fe172_row1_col43, #T_fe172_row1_col45, #T_fe172_row1_col47, #T_fe172_row1_col48, #T_fe172_row1_col49, #T_fe172_row1_col52, #T_fe172_row1_col56, #T_fe172_row1_col66, #T_fe172_row1_col67, #T_fe172_row1_col68, #T_fe172_row1_col69, #T_fe172_row1_col70, #T_fe172_row1_col71, #T_fe172_row1_col75, #T_fe172_row1_col77, #T_fe172_row2_col1, #T_fe172_row2_col44, #T_fe172_row2_col45, #T_fe172_row2_col48, #T_fe172_row2_col49, #T_fe172_row2_col50, #T_fe172_row2_col52, #T_fe172_row2_col67, #T_fe172_row2_col68, #T_fe172_row2_col69, #T_fe172_row2_col70, #T_fe172_row2_col71, #T_fe172_row2_col75, #T_fe172_row2_col77, #T_fe172_row3_col3, #T_fe172_row3_col4, #T_fe172_row3_col17, #T_fe172_row3_col20, #T_f
{
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_fe172_row1_col62 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_fe172_row1_col76, #T_fe172_row2_col76 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_fe172_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_fe172_row2_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_fe172_row2_col4 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_fe172_row2_col19, #T_fe172_row2_col59 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_fe172_row2_col20 {
#   background-color:

# %%
columns = train.columns.to_list()

# %%
print(columns)
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %%
column = test.columns.to_list()
print(columns)
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %% [markdown]
# Hereby I have made a columns list for train data and test data

# %%
categorical_data = train.select_dtypes(include=['object'])
numerical_data = train.select_dtypes(include=['int', 'float'])
categorical_cols = categorical_data.columns.to_list()
numerical_d = test.select_dtypes(include=['int', 'float'])
numerical_cols = numerical_data.columns.to_list()
numerical_col = numerical_d.columns.to_list()
print(numerical_col)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %% [markdown]
# Hereby I have made lists of numerical and categorical columns. Categorical columns are same in Train and Test data while Test data dont have "SalePrice" So I have made another list for numerical columns in Test data.

# %% [markdown]
# # Ideantifying with Missing Values

# %%
plt.figure(figsize=(20,10))
plt.title("Missing Values in Categorical Columns of Train ",fontsize= 20)
sns.heatmap(train[categorical_cols].isnull(),yticklabels=False,cbar=False)
plt.show()
ll11 =[]
for i in categorical_cols:
    mis_per = train[i].isnull().mean()
    if mis_per> 0:
        print(i, mis_per)
        ll11.append(i)
# Out:
# Alley 0.9376712328767123
# MasVnrType 0.005479452054794521
# BsmtQual 0.025342465753424658
# BsmtCond 0.025342465753424658
# BsmtExposure 0.026027397260273973
# BsmtFinType1 0.025342465753424658
# BsmtFinType2 0.026027397260273973
# Electrical 0.0006849315068493151
# FireplaceQu 0.4726027397260274
# GarageType 0.05547945205479452
# GarageFinish 0.05547945205479452
# GarageQual 0.05547945205479452
# GarageCond 0.05547945205479452
# PoolQC 0.9952054794520548
# Fence 0.8075342465753425
# MiscFeature 0.963013698630137

# %%
plt.figure(figsize=(20,10))
plt.title("Missing Values in Numerical Columns of Test ",fontsize= 20)
sns.heatmap(test[numerical_col].isnull(),yticklabels=False,cbar=False)
plt.show()
num_test =[]
for i in numerical_col:
    mis_per = test[i].isnull().mean()
    
    if mis_per>0:
        print(i,mis_per)
        num_test.append(i)
# Out:
# LotFrontage 0.15558601782042494
# MasVnrArea 0.01028101439342015
# BsmtFinSF1 0.0006854009595613434
# BsmtFinSF2 0.0006854009595613434
# BsmtUnfSF 0.0006854009595613434
# TotalBsmtSF 0.0006854009595613434
# BsmtFullBath 0.0013708019191226869
# BsmtHalfBath 0.0013708019191226869
# GarageYrBlt 0.053461274845784786
# GarageCars 0.0006854009595613434
# GarageArea 0.0006854009595613434

# %%
plt.figure(figsize=(20,10))
plt.title("Missing Values in Categorical Columns of Test ",fontsize= 20)
sns.heatmap(test[categorical_cols].isnull(),yticklabels=False,cbar=False)
plt.show()
ll12 =[]
for i in categorical_cols:
    mis_per = test[i].isnull().mean()
    if mis_per> 0:
        print(i,mis_per)
        ll12.append(i)
# Out:
# MSZoning 0.0027416038382453737
# Alley 0.9266620973269363
# Utilities 0.0013708019191226869
# Exterior1st 0.0006854009595613434
# Exterior2nd 0.0006854009595613434
# MasVnrType 0.010966415352981495
# BsmtQual 0.03015764222069911
# BsmtCond 0.030843043180260453
# BsmtExposure 0.03015764222069911
# BsmtFinType1 0.02878684030157642
# BsmtFinType2 0.02878684030157642
# KitchenQual 0.0006854009595613434
# Functional 0.0013708019191226869
# FireplaceQu 0.5003427004797807
# GarageType 0.0520904729266621
# GarageFinish 0.053461274845784786
# GarageQual 0.053461274845784786
# GarageCond 0.053461274845784786
# PoolQC 0.997943797121316
# Fence 0.8012337217272104
# MiscFeature 0.9650445510623715
# SaleType 0.0006854009595613434

# %%
plt.figure(figsize=(20,10))
plt.title("Missing Values in Numeircal Columns of Train ",fontsize= 20)
sns.heatmap(train[numerical_cols].isnull(),yticklabels=False,cbar=False)
plt.show()
num_train =[]
for i in numerical_cols:
    mis_per = train[i].isnull().mean()*100
    if mis_per>0:
        print(i,mis_per)
        num_train.append(i)
# Out:
# LotFrontage 17.73972602739726
# MasVnrArea 0.547945205479452
# GarageYrBlt 5.5479452054794525

# %% [markdown]
# # Description of These Columns
# ## Alley: Type of alley access
#
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
#
# ## BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# ## BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# ## BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# ## BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# ## BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
#
#
# ## GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
#
#
# ## GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# ## GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# ## GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# ## FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# ## Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# ## PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# ## MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# ## Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# ## MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# ## Except 'Electrical' and 'MasVnrType' every other column have another option "NA" which is recongnised as missing value by system. So we will repalce them with "Nor" for all the remaining columns.

# %%
ll11.remove('Electrical')
ll11.remove('MasVnrType')
print(ll11)
# Out:
# ['Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
for i in ll11:
    train[i].fillna("Nor",inplace= True)
    test[i].fillna("Nor",inplace= True)

# %%
from sklearn.impute import SimpleImputer
my_imp = SimpleImputer(strategy="most_frequent")
cll1 = ['Electrical','MasVnrType']

train[cll1] = my_imp.fit_transform(train[cll1])

test[cll1] = my_imp.transform(test[cll1])

# %%
train[cll1] = my_imp.fit_transform(train[cll1])
test[cll1] = my_imp.transform(test[cll1])

# %% [markdown]
# ## Description of Numerical Columns with Missing Values

# %% [markdown]
# LotFrontage: Linear feet of street connected to property
# MasVnrArea: Masonry veneer area in square feet
# GarageYrBlt: Year garage was built

# %% [markdown]
# GarageYrBlt have same no of missing value is other Garage features had so we will update this columns as years since the garage was sold and replace missing with 0.

# %%
train['GarageYrBlt'].fillna(2023,inplace= True)
train['GarageYrBlt'] = 2023 - train['GarageYrBlt']
test['GarageYrBlt'].fillna(2023,inplace= True)
test['GarageYrBlt'] = 2023 - test['GarageYrBlt']
train['YearBuilt'] = 2023 - train['YearBuilt']
test['YearBuilt'] = 2023 - test['YearBuilt']
train['YearRemodAdd'] = 2023 - train['YearBuilt']
test['YearRemodAdd'] = 2023 - test['YearBuilt']
train['YrSold'] = 2023 - train['YrSold']
test['YrSold'] = 2023 - test['YrSold']

# %%
myimp = SimpleImputer(strategy="mean")
train['MasVnrArea']=myimp.fit_transform(train[['MasVnrArea']])
test['MasVnrArea']=myimp.transform(test[['MasVnrArea']])
test['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
train['LotFrontage']=myimp.fit_transform(train[['LotFrontage']])
test['LotFrontage']=myimp.transform(test[['LotFrontage']])
test['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Dealing with missing values in Test set only

# %%
l3 = []
for i in categorical_cols:
    mis_per = test[i].isnull().mean()*100
    if mis_per> 0:
        print(i,mis_per)
        l3.append(i)
print(l3)
# Out:
# MSZoning 0.2741603838245374
# Utilities 0.1370801919122687
# Exterior1st 0.06854009595613435
# Exterior2nd 0.06854009595613435
# KitchenQual 0.06854009595613435
# Functional 0.1370801919122687
# SaleType 0.06854009595613435
# ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'KitchenQual', 'Functional', 'SaleType']

# %%
l4 = []
for i in numerical_col:
    mis_per = test[i].isnull().mean()*100
    if mis_per> 0:
        print(i,mis_per)
        l4.append(i)
print(l4)
# Out:
# BsmtFinSF1 0.06854009595613435
# BsmtFinSF2 0.06854009595613435
# BsmtUnfSF 0.06854009595613435
# TotalBsmtSF 0.06854009595613435
# BsmtFullBath 0.1370801919122687
# BsmtHalfBath 0.1370801919122687
# GarageCars 0.06854009595613435
# GarageArea 0.06854009595613435
# ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']

# %%
catimp = SimpleImputer(strategy="most_frequent")
catimp.fit(train[l3])
test[l3] = catimp.transform(test[l3])
myimp = SimpleImputer()
myimp.fit(train[l4])
test[l4] = myimp.transform(test[l4])
test[l3].isnull().sum()
# Out:
# MSZoning       0
# Utilities      0
# Exterior1st    0
# Exterior2nd    0
# KitchenQual    0
# Functional     0
# SaleType       0
# dtype: int64

# %% [markdown]
# ## Visualization

# %% [markdown]
# Distribution plots of all numerical columns

# %%
train.hist(figsize = (30, 30), bins = 40)
plt.show()

# %%
sns.catplot(data=train, x="BsmtQual", y= "SalePrice",kind="swarm",height =7,aspect =2.5).set(title="Swarm plot of Sale Price with Basement Quality")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 5.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 20.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 27.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
px.histogram(train, x = "OverallQual", y = "SalePrice",color = "HouseStyle")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e74f121d-e1ec-48fa-9adf-d27dc9ca0731" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e74f121d-e1ec-48fa-9adf-d27dc9ca0731")) {                    Plotly.newPlot(                        "e74f121d-e1ec-48fa-9adf-d27dc9ca0731",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"HouseStyle=2Story<br>OverallQual=%{x}<br>sum of SalePrice=%{y}<extra></extra>","legendgroup":"2Story","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"
236000,265979,162000,275500,172500,212000,158900,179400,290000,215200,337000,196500,538000,175900,233000,187500,269790,194500,171000,485000,200000,189000,582933,223500,183000,225000,185000,147400,151000,237000,100000,140000,157500,213000,174000,250000,169000,236000,200500,303477,350000,178000,172500,140000,142953,180000,174000,154300,145000,173733,75000,238000,201000,285000,176000,222000,253000,239799,244400,214000,192500,172000,145000,124000,155000,272000,155000,214900,178900,173000,167500,165000,336000,255900,195000,197000,348000,168000,187000,173900,88000,165000,227000,118000,160000,310000,287000,97000,173000,262280,556 ...

# %%
sns.distplot(train["SalePrice"], color = "black")
# Out:
# /tmp/ipykernel_21/3617509441.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# ## Column Transformation

# %% [markdown]
# We and already transform columns with year above.
# Now we will tranform other columns into more apporipriate form.

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
#
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# train['Time'] = train['YrSold'] - train['YearBuilt']
# train['Total_Area'] = train['GrLivArea'] + train['TotalBsmtSF']
# train['Final_Area'] = train['Total_Area'] + train['GarageArea']
# train['Overall_Plus'] = train['OverallQual'] + train['OverallCond']
# train['Area'] = train['Final_Area'] + train['LotArea']

# %% [markdown]
# test['Time'] = test['YrSold'] - test['YearBuilt']
# test['Total_Area'] = test['GrLivArea'] + test['TotalBsmtSF']
# test['Final_Area'] = test['Total_Area'] + test['GarageArea']
# test['Overall_Plus'] = test['OverallQual'] + test['OverallCond']
# test['Area'] = test['Final_Area'] + test['LotArea']

# %% [markdown]
# train.drop(['YrSold','YearBuilt','GrLivArea','TotalBsmtSF','Total_Area','GarageArea','OverallQual','OverallCond','Final_Area'],axis=1,inplace = True)

# %% [markdown]
# test.drop(['YrSold','YearBuilt','GrLivArea','TotalBsmtSF','Total_Area','GarageArea','OverallQual','OverallCond','Final_Area'],axis=1,inplace = True)

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
label_encoder = OrdinalEncoder()
for i in categorical_cols:
    train[i] = label_encoder.fit_transform(train[[i]])
    test[i] = label_encoder.transform(test[[i]])

# %%
print(numerical_col)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %% [markdown]
# l1 =['Id','YrSold','YearBuilt','GrLivArea','TotalBsmtSF','GarageArea','OverallQual','OverallCond']
# for i in l1:
#     numerical_col.remove(i)

# %% [markdown]
# l2 = ['Area','Overall_Plus']
# for i in l2:
#     numerical_col.append(i)

# %%
numerical_col.remove('Id')

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train[numerical_col] = scaler.fit_transform(train[numerical_col])
test[numerical_col] = scaler.transform(test[numerical_col])

# %%
train.tail(10).style.background_gradient()
# Out:
# <style type="text/css">
, #T_dc0dc_row2_col52, #T_dc0dc_row2_col54, #T_dc0dc_row2_col56, #T_dc0dc_row2_col60, #T_dc0dc_row2_col65, #T_dc0dc_row2_col66, #T_dc0dc_row2_col68, #T_dc0dc_row2_col69, #T_dc0dc_row2_col70, #T_dc0dc_row2_col71, #T_dc0dc_row2_col72, #T_dc0dc_row2_col74, #T_dc0dc_row2_col75, #T_dc0dc_row3_col1, #T_dc0dc_row3_col5, #T_dc0dc_row3_col6, #T_dc0dc_row3_col7, #T_dc0dc_row3_col8, #T_dc0dc_row3_col9, #T_dc0dc_row3_col11, #T_dc0dc_row3_col13, #T_dc0dc_row3_col14, #T_dc0dc_row3_col15, #T_dc0dc_row3_col16, #T_dc0dc_row3_col17, #T_dc0dc_row3_col18, #T_dc0dc_row3_col21, #T_dc0dc_row3_col22, #T_dc0dc_row3_col26, #T_dc0dc_row3_col30, #T_dc0dc_row3_col34, #T_dc0dc_row3_col36, #T_dc0dc_row3_col39, #T_dc0dc_row3_col40, #T_dc0dc_row3_col41, #T_dc0dc_row3_col44, #T_dc0dc_row3_col45, #T_dc0dc_row3_col47, #T_dc0dc_row3_col48, #T_dc0dc_row3_col49, #T_dc0dc_row3_col50, #T_dc0dc_row3_col52, #T_dc0dc_row3_col56, #T_dc0dc_row3_col59, #T_dc0dc_row3_col61, #T_dc0dc_row3_col62, #T_dc0dc_row3_col63, #T_dc0dc_row3_col64, #T_dc0dc_row3_col65, #T_dc0dc_row3_col68, #T_dc0dc_row3_col69, #T_dc0dc_row3_col70, #T_dc0dc_row3_col71, #T_dc0dc_row3_col72, #T_dc0dc_row3_col74, #T_dc0dc_row3_col75, #T_dc0dc_row3_col79, #T_dc0dc_row3_col80, #T_dc0dc_row4_col1, #T_dc0dc_row4_col2, #T_dc0dc_row4_col5, #T_dc0dc_row4_col7, #T_dc0dc_row4_col8, #T_dc0dc_row4_col9, #T_dc0dc_row4_col11, #T_dc0dc_row4_col13, #T_dc0dc_row4_col14, #T_dc0dc_row4_col15, #T_dc0dc_row4_col16, #T_dc0dc_row4_col18, #T_dc0dc_row4_col21, #T_dc0dc_row4_col22, #T_dc0dc_row4_col26, #T_dc0dc_row4_col30, #T_dc0dc_row4_col36, #T_dc0dc_row4_col39, #T_dc0dc_row4_col40, #T_dc0dc_row4_col41, #T_dc0dc_row4_col44, #T_dc0dc_row4_col45, #T_dc0dc_row4_col48, ...

# %%
corr_df = train.corr()
low_corr =corr_df.index[abs(corr_df["SalePrice"]) < 0.4].to_list()
print(len(low_corr))
# Out:
# 62

# %%
low_corr.remove("Id")
print(len(low_corr))
# Out:
# 61

# %% [markdown]
# train.drop(low_corr,axis=1,inplace= True)

# %% [markdown]
# test.drop(low_corr,axis=1,inplace= True)

# %% [markdown]
# plt.figure(figsize=(20,10))
# sns.heatmap(train.corr(),annot=True)

# %%
corr_matrix = train.corr()

high_corr_pairs = [(feat1, feat2, corr_matrix.loc[feat1, feat2]) for feat1 in corr_matrix.columns for feat2 in corr_matrix.columns
                   if corr_matrix.loc[feat1, feat2] > 0.7 and feat1 != feat2]

print("Pairs with correlation above 0.7:")
for pair in high_corr_pairs:
    print(f"{pair[0]} - {pair[1]}: {pair[2]}")
# Out:
# Pairs with correlation above 0.7:
# MSSubClass - BldgType: 0.7460629359877906
# BldgType - MSSubClass: 0.7460629359877906
# OverallQual - SalePrice: 0.790981600583805
# Exterior1st - Exterior2nd: 0.8541629837325787
# Exterior2nd - Exterior1st: 0.8541629837325787
# TotalBsmtSF - 1stFlrSF: 0.8195299750050328
# 1stFlrSF - TotalBsmtSF: 0.8195299750050328
# GrLivArea - TotRmsAbvGrd: 0.8254893743088413
# GrLivArea - SalePrice: 0.7086244776126515
# TotRmsAbvGrd - GrLivArea: 0.8254893743088413
# GarageCars - GarageArea: 0.8824754142814631
# GarageArea - GarageCars: 0.8824754142814631
# SalePrice - OverallQual: 0.790981600583805
# SalePrice - GrLivArea: 0.7086244776126515

# %%
l =['1stFlrSF','TotRmsAbvGrd','GarageArea','SalePrice','OverallQual','TotalBsmtSF','GrLivArea','GarageCars']
sns.pairplot(train[l], corner = True)

# %%
train.drop(['1stFlrSF','TotRmsAbvGrd','GarageArea'],axis=1,inplace= True)
test.drop(['1stFlrSF','TotRmsAbvGrd','GarageArea'],axis=1,inplace= True)

# %%
traindf = train
testdf = test

# %%
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor

# %%
X = traindf.drop(["Id",'SalePrice'],axis=1)
y = traindf['SalePrice']
X_train,X_test,y_train,y_test = train_test_split(X ,y , train_size=0.8 , test_size=0.2, random_state=1)

# %%
 def modd(x):
    l = [50,70,100,120,150,180,200]
    for n in l:
        model = x(n_estimators=n)
        cv_scores = cross_val_score(model,X,y,scoring="neg_mean_squared_error",cv=3)
        test_rmse = np.sqrt(-cv_scores)
        means= test_rmse.mean()
    print(means.mean())

# %%
modd(XGBRegressor)
# Out:
# 30344.192131815525

# %%
modd(RandomForestRegressor)
# Out:
# 29780.14160049369

# %%
modd(GradientBoostingRegressor)
# Out:
# 26657.99503846618

# %%
modd(LGBMRegressor)
# Out:
# 29388.231404387163

# %%
l = [50,70,100,120,150,180,200]
for n in l:
    model = GradientBoostingRegressor(n_estimators=n)
    cv_scores = cross_val_score(model,X,y,scoring="neg_mean_squared_error",cv=3)
    test_rmse = np.sqrt(-cv_scores)
    print(n,test_rmse.mean())
# Out:
# 50 28400.851514061957
# 70 27879.191338034154
# 100 28057.26365649157
# 120 27510.856230566405
# 150 26961.84070005509
# 180 27021.79301846912
# 200 27175.100588627858

# %%
X_train, y_train = traindf.drop(["Id", "SalePrice"], axis=1), traindf['SalePrice']
X_test = testdf.drop("Id", axis=1)
model = GradientBoostingRegressor(n_estimators=5000, learning_rate=0.1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
predictions_df = pd.DataFrame({'Id': testdf['Id'], 'SalePrice': y_pred})
predictions_df.to_csv('predictions.csv', index=False)
