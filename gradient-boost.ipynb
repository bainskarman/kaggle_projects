# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("/kaggle/input/playground-series-s3e16/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s3e16/test.csv")

# %%
train.head(10).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_353af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_353af_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_353af_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_353af_level0_col2" class="col_heading level0 col2" >Length</th>
#       <th id="T_353af_level0_col3" class="col_heading level0 col3" >Diameter</th>
#       <th id="T_353af_level0_col4" class="col_heading level0 col4" >Height</th>
#       <th id="T_353af_level0_col5" class="col_heading level0 col5" >Weight</th>
#       <th id="T_353af_level0_col6" class="col_heading level0 col6" >Shucked Weight</th>
#       <th id="T_353af_level0_col7" class="col_heading level0 col7" >Viscera Weight</th>
#       <th id="T_353af_level0_col8" class="col_heading level0 col8" >Shell Weight</th>
#       <th id="T_353af_level0_col9" class="col_heading level0 col9" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_353af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_353af_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_353af_row0_col1" class="data row0 col1" >I</td>
#       <td id="T_353af_row0_col2" class="data row0 col2" >1.525000</td>
#       <td id="T_353af_row0_col3" class="data row0 col3" >1.175000</td>
#       <td id="T_353af_row0_col4" class="data row0 col4" >0.375000</td>
#       <td id="T_353af_row0_col5" class="data row0 col5" >28.973189</td>
#       <td id="T_353af_row0_col6" class="data row0 col6" >12.728926</td>
#       <td id="T_353af_row0_col7" class="data row0 col7" >6.647958</td>
#       <td id="T_353af_row0_col8" class="data row0 col8" >8.348928</td>
#       <td id="T_353af_row0_col9" class="data row0 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_353af_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_353af_row1_col1" class="data row1 col1" >I</td>
#       <td id="T_353af_row1_col2" class="data row1 col2" >1.100000</td>
#       <td id="T_353af_row1_col3" class="data row1 col3" >0.825000</td>
#       <td id="T_353af_row1_col4" class="data row1 col4" >0.275000</td>
#       <td id="T_353af_row1_col5" class="data row1 col5" >10.418441</td>
#       <td id="T_353af_row1_col6" class="data row1 col6" >4.521745</td>
#       <td id="T_353af_row1_col7" class="data row1 col7" >2.324659</td>
#       <td id="T_353af_row1_col8" class="data row1 col8" >3.401940</td>
#       <td id="T_353af_row1_col9" class="data row1 col9" >8</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_353af_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_353af_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_353af_row2_col2" class="data row2 col2" >1.387500</td>
#       <td id="T_353af_row2_col3" class="data row2 col3" >1.112500</td>
#       <td id="T_353af_row2_col4" class="data row2 col4" >0.375000</td>
#       <td id="T_353af_row2_col5" class="data row2 col5" >24.777463</td>
#       <td id="T_353af_row2_col6" class="data row2 col6" >11.339800</td>
#       <td id="T_353af_row2_col7" class="data row2 col7" >5.556502</td>
#       <td id="T_353af_row2_col8" class="data row2 col8" >6.662133</td>
#       <td id="T_353af_row2_col9" class="data row2 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_353af_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_353af_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_353af_row3_col2" class="data row3 col2" >1.700000</td>
#       <td id="T_353af_row3_col3" class="data row3 col3" >1.412500</td>
#       <td id="T_353af_row3_col4" class="data row3 col4" >0.500000</td>
#       <td id="T_353af_row3_col5" class="data row3 col5" >50.660556</td>
#       <td id="T_353af_row3_col6" class="data row3 col6" >20.354941</td>
#       <td id="T_353af_row3_col7" class="data row3 col7" >10.991839</td>
#       <td id="T_353af_row3_col8" class="data row3 col8" >14.996885</td>
#       <td id="T_353af_row3_col9" class="data row3 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_353af_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_353af_row4_col1" class="data row4 col1" >I</td>
#       <td id="T_353af_row4_col2" class="data row4 col2" >1.250000</td>
#       <td id="T_353af_row4_col3" class="data row4 col3" >1.012500</td>
#       <td id="T_353af_row4_col4" class="data row4 col4" >0.337500</td>
#       <td id="T_353af_row4_col5" class="data row4 col5" >23.289114</td>
#       <td id="T_353af_row4_col6" class="data row4 col6" >11.977664</td>
#       <td id="T_353af_row4_col7" class="data row4 col7" >4.507570</td>
#       <td id="T_353af_row4_col8" class="data row4 col8" >5.953395</td>
#       <td id="T_353af_row4_col9" class="data row4 col9" >8</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_353af_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_353af_row5_col1" class="data row5 col1" >M</td>
#       <td id="T_353af_row5_col2" class="data row5 col2" >1.500000</td>
#       <td id="T_353af_row5_col3" class="data row5 col3" >1.175000</td>
#       <td id="T_353af_row5_col4" class="data row5 col4" >0.412500</td>
#       <td id="T_353af_row5_col5" class="data row5 col5" >28.845616</td>
#       <td id="T_353af_row5_col6" class="data row5 col6" >13.409313</td>
#       <td id="T_353af_row5_col7" class="data row5 col7" >6.789705</td>
#       <td id="T_353af_row5_col8" class="data row5 col8" >7.937860</td>
#       <td id="T_353af_row5_col9" class="data row5 col9" >10</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_353af_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_353af_row6_col1" class="data row6 col1" >M</td>
#       <td id="T_353af_row6_col2" class="data row6 col2" >1.575000</td>
#       <td id="T_353af_row6_col3" class="data row6 col3" >1.137500</td>
#       <td id="T_353af_row6_col4" class="data row6 col4" >0.350000</td>
#       <td id="T_353af_row6_col5" class="data row6 col5" >30.022120</td>
#       <td id="T_353af_row6_col6" class="data row6 col6" >11.935140</td>
#       <td id="T_353af_row6_col7" class="data row6 col7" >7.342521</td>
#       <td id="T_353af_row6_col8" class="data row6 col8" >8.646598</td>
#       <td id="T_353af_row6_col9" class="data row6 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_353af_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_353af_row7_col1" class="data row7 col1" >I</td>
#       <td id="T_353af_row7_col2" class="data row7 col2" >1.312500</td>
#       <td id="T_353af_row7_col3" class="data row7 col3" >1.025000</td>
#       <td id="T_353af_row7_col4" class="data row7 col4" >0.350000</td>
#       <td id="T_353af_row7_col5" class="data row7 col5" >18.299602</td>
#       <td id="T_353af_row7_col6" class="data row7 col6" >8.249704</td>
#       <td id="T_353af_row7_col7" class="data row7 col7" >3.898056</td>
#       <td id="T_353af_row7_col8" class="data row7 col8" >5.669900</td>
#       <td id="T_353af_row7_col9" class="data row7 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_353af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_353af_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_353af_row8_col1" class="data row8 col1" >F</td>
#       <td id="T_353af_row8_col2" class="data row8 col2" >1.600000</td>
#       <td id="T_353af_row8_col3" class="data row8 col3" >1.287500</td>
#       <td id="T_353af_row8_col4" class="data row8 col4" >0.437500</td>
#       <td id="T_353af_row8_col5" class="data row8 col5" >38.824640</td>
#       <td id="T_353af_row8_col6" class="data row8 col6" >16.967176</td>
#       <td id="T_353af_row8_col7" class="data row8 col7" >7.413394</td>
#       <td id="T_353af_row8_col8" class="data row8 col8" >10.772810</td>
#       <td id="T_353af_row8_col9" class="da

# %%
train.shape
# Out:
# (74051, 10)

# %%
test.shape
# Out:
# (49368, 9)

# %%
train.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_bb57c_row0_col0, #T_bb57c_row0_col3, #T_bb57c_row1_col0, #T_bb57c_row1_col1, #T_bb57c_row1_col2, #T_bb57c_row1_col4, #T_bb57c_row1_col5, #T_bb57c_row1_col6, #T_bb57c_row1_col7, #T_bb57c_row2_col0, #T_bb57c_row2_col1, #T_bb57c_row2_col2, #T_bb57c_row2_col4, #T_bb57c_row2_col5, #T_bb57c_row2_col6, #T_bb57c_row2_col7, #T_bb57c_row3_col0, #T_bb57c_row3_col1, #T_bb57c_row3_col2, #T_bb57c_row3_col3, #T_bb57c_row3_col4, #T_bb57c_row3_col5, #T_bb57c_row3_col6, #T_bb57c_row3_col7, #T_bb57c_row4_col0, #T_bb57c_row4_col1, #T_bb57c_row4_col2, #T_bb57c_row4_col4, #T_bb57c_row4_col5, #T_bb57c_row4_col6, #T_bb57c_row4_col7, #T_bb57c_row5_col0, #T_bb57c_row5_col1, #T_bb57c_row5_col2, #T_bb57c_row5_col4, #T_bb57c_row5_col5, #T_bb57c_row5_col6, #T_bb57c_row5_col7, #T_bb57c_row6_col0, #T_bb57c_row6_col1, #T_bb57c_row6_col2, #T_bb57c_row6_col4, #T_bb57c_row6_col5, #T_bb57c_row6_col6, #T_bb57c_row6_col7, #T_bb57c_row7_col0, #T_bb57c_row7_col1, #T_bb57c_row7_col2, #T_bb57c_row7_col4, #T_bb57c_row7_col5, #T_bb57c_row7_col6, #T_bb57c_row7_col7, #T_bb57c_row8_col0, #T_bb57c_row8_col1, #T_bb57c_row8_col2, #T_bb57c_row8_col4, #T_bb57c_row8_col5, #T_bb57c_row8_col6, #T_bb57c_row8_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bb57c_row0_col1, #T_bb57c_row0_col2, #T_bb57c_row0_col4, #T_bb57c_row0_col5, #T_bb57c_row0_col6, #T_bb57c_row0_col7, #T_bb57c_row8_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bb57c_row1_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_bb57c_row2_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_bb57c_row4_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bb57c_row5_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_bb57c_row6_col3, #T_bb57c_row7_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# </style>
# <table id="T_bb57c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb57c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_bb57c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_bb57c_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_bb57c_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_bb57c_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_bb57c_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_bb57c_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_bb57c_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb57c_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_bb57c_row0_col0" class="data row0 col0" >74051.000000</td>
#       <td id="T_bb57c_row0_col1" class="data row0 col1" >37025.000000</td>
#       <td id="T_bb57c_row0_col2" class="data row0 col2" >21376.826729</td>
#       <td id="T_bb57c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T
#       <td id="T_bb57c_row5_col0" class="data row5 col0" >74051.000000</td>
#       <td id="T_bb57c_row5_col1" class="data row5 col1" >10.104270</td>
#       <td id="T_bb57c_row5_col2" class="data row5 col2" >5.618025</td>
#       <td id="T_bb57c_row5_col3" class="data row5 col3" >0.028349</td>
#       <td id="T_bb57c_row5_col4" class="data row5 col4" >5.712424</td>
#       <td id="T_bb57c_row5_col5" class="data row5 col5" >9.908150</td>
#       <td id="T_bb57c_row5_col6" class="data row5 col6" >14.033003</td>
#       <td id="T_bb57c_row5_col7" class="data row5 col7" >42.184056</td>
#     </tr>
#     <tr>
#       <th id="T_bb57c_level0_row6" class="row_heading level0 row6" >Viscera Weight</th>
#       <td id="T_bb57c_row6_col0" class="data row6 col0" >74051.000000</td>
#       <td id="T_bb57c_row6_col1" class="data row6 col1" >5.058386</td>
#       <td id="T_bb57c_row6_col2" class="data row6 col2" >2.792729</td>
#       <td id="T_bb57c_row6_col3" class="data row6 col3" >0.042524</td>
#       <td id="T_bb57c_row6_col4" class="data row6 col4" >2.863300</td>
#       <td id="T_bb57c_row6_col5" class="data row6 col5" >4.989512</td>
#       <td id="T_bb57c_row6_col6" class="data row6 col6" >6.988152</td>
#       <td id="T_bb57c_row6_col7" class="data row6 col7" >21.545620</td>
#     </tr>
#     <tr>
#       <th id="T_bb57c_level0_row7" class="row_heading level0 row7" >Shell Weight</th>
#       <td id="T_bb57c_row7_col0" class="data row7 col0" >74051.000000</td>
#       <td id="T_bb57c_row7_col1" class="data row7 col1" >6.723870</td>
#       <td id="T_bb57c_row7_col2" class="data row7 col2" >3.584372</td>
#       <td id="T_bb57c_row7_col3" class="data row7 col3" >0.042524</td>
#       <td id="T_bb57c_row7_col4" class="data row7 col4" >3.968930</td>
#       <td id="T_bb57c_row7_col5" class="data row7 col5" >6.931453</td>
#       <td id="T_bb57c_row7_col6" class="data row7 col6" >9.071840</td>
#       <td id="T_bb57c_row7_col7" class="data row7 col7" >28.491248</td>
#     </tr>
#     <tr>
#       <th i

# %%
test.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_23b91_row0_col0, #T_23b91_row1_col0, #T_23b91_row1_col1, #T_23b91_row1_col2, #T_23b91_row1_col3, #T_23b91_row1_col4, #T_23b91_row1_col5, #T_23b91_row1_col6, #T_23b91_row1_col7, #T_23b91_row2_col0, #T_23b91_row2_col1, #T_23b91_row2_col2, #T_23b91_row2_col3, #T_23b91_row2_col4, #T_23b91_row2_col5, #T_23b91_row2_col6, #T_23b91_row2_col7, #T_23b91_row3_col0, #T_23b91_row3_col1, #T_23b91_row3_col2, #T_23b91_row3_col3, #T_23b91_row3_col4, #T_23b91_row3_col5, #T_23b91_row3_col6, #T_23b91_row3_col7, #T_23b91_row4_col0, #T_23b91_row4_col1, #T_23b91_row4_col2, #T_23b91_row4_col3, #T_23b91_row4_col4, #T_23b91_row4_col5, #T_23b91_row4_col6, #T_23b91_row4_col7, #T_23b91_row5_col0, #T_23b91_row5_col1, #T_23b91_row5_col2, #T_23b91_row5_col3, #T_23b
train.isnull().mean()*100
# Out:
# id                0.0
# Sex               0.0
# Length            0.0
# Diameter          0.0
# Height            0.0
# Weight            0.0
# Shucked Weight    0.0
# Viscera Weight    0.0
# Shell Weight      0.0
# Age               0.0
# dtype: float64

# %%
test.isnull().mean()*100
# Out:
# id                0.0
# Sex               0.0
# Length            0.0
# Diameter          0.0
# Height            0.0
# Weight            0.0
# Shucked Weight    0.0
# Viscera Weight    0.0
# Shell Weight      0.0
# dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=train.corr(),annot=True,cbar=False)
# Out:
# /tmp/ipykernel_20/1454998939.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=train.corr(),annot=True,cbar=False)
# <Axes: >

# %%
train['Sex'].unique()
# Out:
# array(['I', 'M', 'F'], dtype=object)

# %%
train['Sex'].value_counts()
# Out:
# M    27084
# I    23957
# F    23010
# Name: Sex, dtype: int64

# %%
cols = train.columns.to_list()
cols.remove('id')
cols
# Out:
# ['Sex',
#  'Length',
#  'Diameter',
#  'Height',
#  'Weight',
#  'Shucked Weight',
#  'Viscera Weight',
#  'Shell Weight',
#  'Age']

# %%
train.hist(figsize=(20,20),bins=40)
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Weight'}>,
#         <Axes: title={'center': 'Shucked Weight'}>],
#        [<Axes: title={'center': 'Viscera Weight'}>,
#         <Axes: title={'center': 'Shell Weight'}>,
#         <Axes: title={'center': 'Age'}>]], dtype=object)

# %%
cols = train.columns
cols = cols.to_list()
print(cols)
# Out:
# ['id', 'Sex', 'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight', 'Viscera Weight', 'Shell Weight', 'Age']

# %%
for i in cols:
    sns.scatterplot(data=train,x=i,y='Age')
    plt.show()

# %%
correlations = train.corrwith(train['Age'])
correlations = abs(correlations)
correlations
# Out:
# /tmp/ipykernel_20/1721525548.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = train.corrwith(train['Age'])
# id                0.000089
# Length            0.612843
# Diameter          0.621256
# Height            0.638067
# Weight            0.601195
# Shucked Weight    0.503320
# Viscera Weight    0.576808
# Shell Weight      0.663473
# Age               1.000000
# dtype: float64

# %%
sns.distplot(train["Age"], color = "black")
# Out:
# /tmp/ipykernel_20/2641269692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train["Age"], color = "black")
# <Axes: xlabel='Age', ylabel='Density'>

# %%
cols.remove('id')
cols.remove('Age')
cols
# Out:
# ['Sex',
#  'Length',
#  'Diameter',
#  'Height',
#  'Weight',
#  'Shucked Weight',
#  'Viscera Weight',
#  'Shell Weight']

# %%
cols.remove('Sex')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.transform(test[cols])

# %%
train
# Out:
#           id Sex    Length  Diameter    Height    Weight  Shucked Weight  \
# 0          0   I  0.732750  0.703390  0.132743  0.361254        0.301278
# 1          1   I  0.499914  0.466102  0.097345  0.129449        0.106590
# 2          2   M  0.657421  0.661017  0.132743  0.308837        0.268325
# 3          3   F  0.828624  0.864407  0.176991  0.632194        0.482179
# 4          4   I  0.582091  0.593220  0.119469  0.290243        0.283457
# ...      ...  ..       ...       ...       ...       ...             ...
# 74046  74046   F  0.808080  0.762712  0.154867  0.632194        0.489913
# 74047  74047   I  0.486218  0.491525  0.097345  0.129803        0.101883
# 74048  74048   F  0.712206  0.720339  0.146018  0.367629        0.291190
# 74049  74049   I  0.561547  0.559322  0.110619  0.208783        0.212172
# 74050  74050   I  0.397192  0.364407  0.070796  0.066584        0.048083
#
#        Viscera Weight  Shell Weight  Age
# 0            0.307185      0.291978    9
# 1            0.106131      0.118087    8
# 2            0.256427      0.232686    9
# 3            0.509197      0.525660   11
# 4            0.207647      0.207773    8
# ...               ...           ...  ...
# 74046        0.479895      0.431988   10
# 74047        0.104812      0.123069    6
# 74048        0.348715      0.282511   10
# 74049        0.133817      0.148979    8
# 74050        0.046144      0.058296    6
#
# [74051 rows x 10 columns]

# %%
train.hist(figsize=(20,20),bins=40)
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Weight'}>,
#         <Axes: title={'center': 'Shucked Weight'}>],
#        [<Axes: title={'center': 'Viscera Weight'}>,
#         <Axes: title={'center': 'Shell Weight'}>,
#         <Axes: title={'center': 'Age'}>]], dtype=object)

# %%
train = pd.get_dummies(train, columns=['Sex'])
test = pd.get_dummies(test, columns=['Sex'])

# %%
train
# Out:
#           id    Length  Diameter    Height    Weight  Shucked Weight  \
# 0          0  0.732750  0.703390  0.132743  0.361254        0.301278
# 1          1  0.499914  0.466102  0.097345  0.129449        0.106590
# 2          2  0.657421  0.661017  0.132743  0.308837        0.268325
# 3          3  0.828624  0.864407  0.176991  0.632194        0.482179
# 4          4  0.582091  0.593220  0.119469  0.290243        0.283457
# ...      ...       ...       ...       ...       ...             ...
# 74046  74046  0.808080  0.762712  0.154867  0.632194        0.489913
# 74047  74047  0.486218  0.491525  0.097345  0.129803        0.101883
# 74048  74048  0.712206  0.720339  0.146018  0.367629        0.291190
# 74049  74049  0.561547  0.559322  0.110619  0.208783        0.212172
# 74050  74050  0.397192  0.364407  0.070796  0.066584        0.048083
#
#        Viscera Weight  Shell Weight  Age  Sex_F  Sex_I  Sex_M
# 0            0.307185      0.291978    9      0      1      0
# 1            0.106131      0.118087    8      0      1      0
# 2            0.256427      0.232686    9      0      0      1
# 3            0.509197      0.525660   11      1      0      0
# 4            0.207647      0.207773    8      0      1      0
# ...               ...           ...  ...    ...    ...    ...
# 74046        0.479895      0.431988   10      1      0      0
# 74047        0.104812      0.123069    6      0      1      0
# 74048        0.348715      0.282511   10      1      0      0
# 74049        0.133817      0.148979    8      0      1      0
# 74050        0.046144      0.058296    6      0      1      0
#
# [74051 rows x 12 columns]

# %%
train.hist(figsize=(20,20),bins=40)
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Weight'}>,
#         <Axes: title={'center': 'Shucked Weight'}>],
#        [<Axes: title={'center': 'Viscera Weight'}>,
#         <Axes: title={'center': 'Shell Weight'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Sex_F'}>,
#         <Axes: title={'center': 'Sex_I'}>,
#         <Axes: title={'center': 'Sex_M'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %%
X = train.drop(["id",'Age'],axis=1)
y = train['Age']
X_train,X_test,y_train,y_test = train_test_split(X ,y , train_size=0.7 , test_size=0.3, random_state=1)

# %%
l = []
p = [20,40,50,70,100,120,150,180]
for n in p:
    model = XGBRegressor(n_estimators= n)
    model.fit(X_train,y_train)
    cv_scores = cross_val_score(model,X,y,scoring="neg_mean_squared_error",cv=3)
    test_rmse = np.sqrt(-cv_scores)
    means= test_rmse.mean()
    print(means)
    l.append(means)
# Out:
# 2.055514456790253
# 2.060267243697245
# 2.0636575234293484
# 2.072267492349347
# 2.080116431944838
# 2.0854364284659135
# 2.0945466938317323
# 2.1029468042698674

# %%
sns.lineplot(x=l, y=p)
# Out:
# <Axes: >

# %%
l = []
p = [20,40,50,70,100,120,150,180]
for n in p:
    model = GradientBoostingRegressor(n_estimators=n)
    model.fit(X_train,y_train)
    cv_scores = cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=3)
    test_rmse = np.sqrt(-cv_scores)
    means= test_rmse.mean()
    l.append(means)
    print(means)
# Out:
# 2.1969712704159856
# 2.109002289096128
# 2.0946933516324204
# 2.0771744408104844
# 2.064516206572204
# 2.060626182607126
# 2.056556993699369
# 2.054366775004335

# %%
sns.lineplot(x=p, y=l)
# Out:
# <Axes: >

# %%
l = []
p = [100,200,300,400,500]
lr= [0.01, 0.1, 0.5]
param_grid ={'n_estimators':p,'learning_rate': lr}
grid_search = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='neg_mean_squared_error')

# %%
best_n_estimators = grid_search.best_params_['n_estimators']
best_learning_rate = grid_search.best_params_['learning_rate']
model = GradientBoostingRegressor(n_estimators=best_n_estimators, learning_rate=best_learning_rate)

# %%
model.fit(X_train,y_train)
cv_scores = cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=3)
test_rmse = np.sqrt(-cv_scores)
means= test_rmse.mean()
l.append(means)
print(means)
# Out:
# 2.049584100613636

# %%
best_n_estimators
# Out:
# 300

# %%
best_n_estimators
# Out:
# 300

# %%
X_train, y_train = train.drop(["id",'Age'], axis=1), train['Age']
X_test = test.drop("id", axis=1)
model = GradientBoostingRegressor(n_estimators=best_n_estimators,learning_rate=best_n_estimators)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:288: RuntimeWarning: overflow encountered in multiply
#   raw_predictions[:, k] += learning_rate * tree.predict(X).ravel()
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))

# %%
predictions_df = pd.DataFrame({'id': test['id'], 'Age': y_pred})
predictions_df.to_csv('predictions.csv', index=False)
